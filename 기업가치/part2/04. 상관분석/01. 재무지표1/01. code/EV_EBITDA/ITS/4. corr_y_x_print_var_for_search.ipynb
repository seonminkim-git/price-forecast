# %%
import pandas as pd
import numpy as np
import os
from scipy.cluster import hierarchy as hc
import matplotlib
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
from scipy import stats
import math
import sys

sys.path.insert(0, 'C:\\Users\\10188\\Desktop\\기업가치\\상관분석\\기업가치분석_code')
# sys.path.append('C:\\Users\\10123\\기업가치분석')
from code_all import * 
# %matplotlib inline
warnings.filterwarnings(action='ignore')

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %% [markdown]
# # Load data

# %%
# dir_root = 'C:/Users/kkt71/OneDrive/바탕 화면/기업가치분석'
dir_root = '../../../../../'
dir_master = os.path.join(dir_root,'01. Data','00. master_data')
dir_processed = os.path.join(dir_root, '01. Data','01. 재무지표1', 'ITS')
dir_result = os.path.join(dir_root, '04. 상관분석','01. 재무지표1','02. result')

# %% [markdown]
# # Correlation Y~X

# %%
master_file_name = 'desc_v2.2.xlsx'
version_processed = 'v1_3'

# %% [markdown]
# ## Accenture

# %% [markdown]
# ### Load data, set parameter

# %%
company = 'Accenture'

# %%
df = pd.read_csv(os.path.join(dir_processed, version_processed, company+'_non_shift_clean_v1.3.csv'))
master = pd.read_excel(os.path.join(dir_master, master_file_name), sheet_name='desc')

# %%
df['Date_x'] = pd.to_datetime(df['Date_x'])
# df['Date_quarter'] = pd.to_datetime(df['Date_quarter'])
# df = df.drop('Unnamed: 0', axis=1)
master = master.drop('Unnamed: 0', axis=1)
# master = master.iloc[:,:5]
# master.columns = master.iloc[0,:]
# master = master.drop(0, axis=0).reset_index(drop=True)

# %%
y = 'EV_EBITDA'
y_name = 'EV_EBITDA'
date = 'Date_x'
col = [y]+[x for x in df.columns if (x not in [date, y, 'close_weighted', 'close', 'PBR', 'EBITDA2(천원)'])]
# col = [y]+[x for x in df.columns if (x not in [date, y, 'Close_weighted'])]

# %%
dir_company = os.path.join(dir_result, company)

if os.path.exists(dir_company)==False:
    os.makedirs(dir_company)

# %% [markdown]
# ### Calculate corr

# %% [markdown]
# #### Total

# %%
result = cal_corr(df, master, company, y, date, col, False)

# %%
dir_company_y = os.path.join(dir_company, y)

if os.path.exists(dir_company_y)==False:
    os.makedirs(dir_company_y)

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# #### Total

# %%
scatter_plot_for_search(df, result, False, y_name, company)
# Out:
# 안정성
# Accenture
# BPS(지배, Adj.)(원/주)
# Accenture
# 단기투자자산
# Accenture
# 무형자산
# Accenture
# 무형자산감상비 누계
# Accenture
# 부채비율(비율)
# Accenture
# 부채총계(천원)
# Accenture
# 비유동비율(천원)
# Accenture
# 비유동자산(천원)
# Accenture
# 순부채(천원)
# Accenture
# 운전자본증감(천원)
# Accenture
# 유동비율(비율)
# Accenture
# 유동자산(천원)
# Accenture
# 유형자산감상비 누계
# Accenture
# 이자보상율
# Accenture
# 자기자본비율
# Accenture
# 자산총계(천원)
# Accenture
# 채무총계
# 성장성
# Accenture
# BPS증가율(YoY)(비율)
# Accenture
# CAPEX(천원)
# Accenture
# EBITDA2증가율(YoY)(비율)
# Accenture
# EPS증가율(YoY)(비율)
# Accenture
# Gross Investment (GI)
# Accenture
# 매출액(천원)
# Accenture
# 매출액증가율(YoY)(연도)
# Accenture
# 매출원가(천원)
# Accenture
# 순이익증가율(YoY)(비율)
# Accenture
# 영업이익증가율(YoY)(연도)
# Accenture
# 인당매출s
# Accenture
# 투자비 대비 매출 (Rev/GI)s
# 수익성
# Accenture
# EBIT(천원)
# Accenture
# EBITDA2마진율(비율)
# Accenture
# EPS(지배, Adj.)(원/주)
# Accenture
# Free Cash Flow2(천원)
# Accenture
# Opex Margin
# Accenture
# ROA(비율)
# Accenture
# ROE(지배)(비율)
# Accenture
# ROGI(%)
# Accenture
# SG&A
# ...

# %% [markdown]
# ## Infosys

# %% [markdown]
# ### Load data, set parameter

# %%
company = 'Infosys'

# %%
df = pd.read_csv(os.path.join(dir_processed, version_processed, company+'_non_shift_clean_v1.3.csv'))
master = pd.read_excel(os.path.join(dir_master, master_file_name), sheet_name='desc')

# %%
df['Date_x'] = pd.to_datetime(df['Date_x'])
# df['Date_quarter'] = pd.to_datetime(df['Date_quarter'])
# df = df.drop('Unnamed: 0', axis=1)
master = master.drop('Unnamed: 0', axis=1)
# master = master.iloc[:,:5]
# master.columns = master.iloc[0,:]
# master = master.drop(0, axis=0).reset_index(drop=True)

# %%
y = 'EV_EBITDA'
y_name = 'EV_EBITDA'
date = 'Date_x'
col = [y]+[x for x in df.columns if (x not in [date, y, 'close_weighted', 'close', 'PBR', 'EBITDA2(천원)'])]
# col = [y]+[x for x in df.columns if (x not in [date, y, 'Close_weighted'])]

# %%
dir_company = os.path.join(dir_result, company)

if os.path.exists(dir_company)==False:
    os.makedirs(dir_company)

# %% [markdown]
# ### Calculate corr

# %% [markdown]
# #### Total

# %%
result = cal_corr(df, master, company, y, date, col, False)

# %%
dir_company_y = os.path.join(dir_company, y)

if os.path.exists(dir_company_y)==False:
    os.makedirs(dir_company_y)

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# #### Total

# %%
scatter_plot_for_search(df, result, False, y_name, company)
# Out:
# 안정성
# Infosys
# 이자보상율
# Infosys
# 유동자산(천원)
# Infosys
# 유동비율(비율)
# Infosys
# 부채총계(천원)
# Infosys
# 채무총계
# Infosys
# 유형자산감상비 누계
# Infosys
# 운전자본증감(천원)
# Infosys
# 순부채(천원)
# Infosys
# 부채비율(비율)
# Infosys
# 자산총계(천원)
# Infosys
# 비유동자산(천원)
# Infosys
# 단기투자자산
# Infosys
# 무형자산
# Infosys
# 비유동비율(천원)
# Infosys
# 자본금(천원)
# Infosys
# BPS(지배, Adj.)(원/주)
# Infosys
# 무형자산감상비 누계
# Infosys
# 자기자본비율
# 수익성
# Infosys
# EPS(지배, Adj.)(원/주)
# Infosys
# 당기순이익(천원)
# Infosys
# 매출총이익(천원)
# Infosys
# Opex Margin
# Infosys
# 이익잉여금(천원)
# Infosys
# 매출액이익률(비율)
# Infosys
# 순이익률(비율)
# Infosys
# ROA(비율)
# Infosys
# 영업이익(천원)
# Infosys
# ROE(지배)(비율)
# Infosys
# SG&A
# Infosys
# 인당순이익s
# Infosys
# EBIT(천원)
# Infosys
# 영업이익률(비율)
# Infosys
# ROGI(%)
# Infosys
# Free Cash Flow2(천원)
# Infosys
# 인당영업이익s
# Infosys
# 현금배당성향(%)
# Infosys
# EBITDA2마진율(비율)
# 활동성
# Infosys
# 매입채무회전율
# Infosys
# 재고자산회전율(비율)
# Infosys
# 매출채권회전율
# Infosys
# 무형자산회전율s
# Infosys
# 총자산회전율(비율)
# 성장성
# Infosys
# 인당매출s
# Infosys
# 매출액(천원)
# Infosys
# ...

# %% [markdown]
# ## TCS

# %% [markdown]
# ### Load data, set parameter

# %%
company = 'TCS'

# %%
df = pd.read_csv(os.path.join(dir_processed, version_processed, company+'_non_shift_clean_v1.4.csv'))
master = pd.read_excel(os.path.join(dir_master, master_file_name), sheet_name='desc')

# %%
df['Date_x'] = pd.to_datetime(df['Date_x'])
# df['Date_quarter'] = pd.to_datetime(df['Date_quarter'])
# df = df.drop('Unnamed: 0', axis=1)
master = master.drop('Unnamed: 0', axis=1)
# master = master.iloc[:,:5]
# master.columns = master.iloc[0,:]
# master = master.drop(0, axis=0).reset_index(drop=True)

# %%
y = 'EV_EBITDA'
y_name = 'EV_EBITDA'
date = 'Date_x'
col = [y]+[x for x in df.columns if (x not in [date, y, 'close_weighted', 'close', 'PBR', 'EBITDA2(천원)'])]
# col = [y]+[x for x in df.columns if (x not in [date, y, 'Close_weighted'])]

# %%
dir_company = os.path.join(dir_result, company)

if os.path.exists(dir_company)==False:
    os.makedirs(dir_company)

# %% [markdown]
# ### Calculate corr

# %% [markdown]
# #### Total

# %%
result = cal_corr(df, master, company, y, date, col, False)

# %%
dir_company_y = os.path.join(dir_company, y)

if os.path.exists(dir_company_y)==False:
    os.makedirs(dir_company_y)

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# #### Total

# %%
scatter_plot_for_search(df, result, False, y_name, company)
# Out:
# 성장성
# TCS
# EBITDA2증가율(YoY)(비율)
# TCS
# 매출원가(천원)
# TCS
# CAPEX(천원)
# TCS
# 인당매출s
# TCS
# EPS증가율(YoY)(비율)
# TCS
# 매출액증가율(YoY)(연도)
# TCS
# Gross Investment (GI)
# TCS
# 투자비 대비 매출 (Rev/GI)s
# TCS
# 영업이익증가율(YoY)(연도)
# TCS
# 순이익증가율(YoY)(비율)
# TCS
# 매출액(천원)
# TCS
# BPS증가율(YoY)(비율)
# 안정성
# TCS
# 이자보상율
# TCS
# 유동비율(비율)
# TCS
# 부채총계(천원)
# TCS
# 부채비율(비율)
# TCS
# 자본금(천원)
# TCS
# 유동자산(천원)
# TCS
# 유형자산감상비 누계
# TCS
# 순부채(천원)
# TCS
# 무형자산감상비 누계
# TCS
# BPS(지배, Adj.)(원/주)
# TCS
# 비유동자산(천원)
# TCS
# 단기투자자산
# TCS
# 자기자본비율
# TCS
# 비유동비율(천원)
# TCS
# 채무총계
# TCS
# 무형자산
# TCS
# 운전자본증감(천원)
# TCS
# 자산총계(천원)
# 수익성
# TCS
# ROGI(%)
# TCS
# ROE(지배)(비율)
# TCS
# 이익잉여금(천원)
# TCS
# SG&A
# TCS
# 현금배당성향(%)
# TCS
# EPS(지배, Adj.)(원/주)
# TCS
# 인당영업이익s
# TCS
# ROA(비율)
# TCS
# 영업이익(천원)
# TCS
# 매출액이익률(비율)
# TCS
# 매출총이익(천원)
# TCS
# 영업이익률(비율)
# TCS
# EBITDA2마진율(비율)
# TCS
# Free Cash Flow2(천원)
# TCS
# 당기순이익(천원)
# TCS
# Opex Margin
# TCS
# EBIT(천원)
# TCS
# 인당순이익s
# TCS
# 순이익률(비율)
# 활동성
# TCS
# 매출채권회전율
# TCS
# 매입채무회전율
# TCS
# ...

# %% [markdown]
# ## Cognizant

# %% [markdown]
# ### Load data, set parameter

# %%
company = 'Cognizant'

# %%
df = pd.read_csv(os.path.join(dir_processed, version_processed, company+'_non_shift_clean_v1.3.csv'))
master = pd.read_excel(os.path.join(dir_master, master_file_name), sheet_name='desc')

# %%
df['Date_x'] = pd.to_datetime(df['Date_x'])
# df['Date_quarter'] = pd.to_datetime(df['Date_quarter'])
# df = df.drop('Unnamed: 0', axis=1)
master = master.drop('Unnamed: 0', axis=1)
# master = master.iloc[:,:5]
# master.columns = master.iloc[0,:]
# master = master.drop(0, axis=0).reset_index(drop=True)

# %%
y = 'EV_EBITDA'
y_name = 'EV_EBITDA'
date = 'Date_x'
col = [y]+[x for x in df.columns if (x not in [date, y, 'close_weighted', 'close', 'PBR', 'EBITDA2(천원)'])]
# col = [y]+[x for x in df.columns if (x not in [date, y, 'Close_weighted'])]

# %%
dir_company = os.path.join(dir_result, company)

if os.path.exists(dir_company)==False:
    os.makedirs(dir_company)

# %% [markdown]
# ### Calculate corr

# %% [markdown]
# #### Total

# %%
result = cal_corr(df, master, company, y, date, col, False)

# %%
dir_company_y = os.path.join(dir_company, y)

if os.path.exists(dir_company_y)==False:
    os.makedirs(dir_company_y)

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# #### Total

# %%
scatter_plot_for_search(df, result, False, y_name, company)
# Out:
# 안정성
# Cognizant
# 이자보상율
# Cognizant
# 유동자산(천원)
# Cognizant
# 유동비율(비율)
# Cognizant
# 부채총계(천원)
# Cognizant
# 채무총계
# Cognizant
# 유형자산감상비 누계
# Cognizant
# 운전자본증감(천원)
# Cognizant
# 순부채(천원)
# Cognizant
# 부채비율(비율)
# Cognizant
# 자산총계(천원)
# Cognizant
# 비유동자산(천원)
# Cognizant
# 단기투자자산
# Cognizant
# 무형자산
# Cognizant
# 비유동비율(천원)
# Cognizant
# 자본금(천원)
# Cognizant
# BPS(지배, Adj.)(원/주)
# Cognizant
# 무형자산감상비 누계
# Cognizant
# 자기자본비율
# 수익성
# Cognizant
# EPS(지배, Adj.)(원/주)
# Cognizant
# 당기순이익(천원)
# Cognizant
# 매출총이익(천원)
# Cognizant
# Opex Margin
# Cognizant
# 이익잉여금(천원)
# Cognizant
# 매출액이익률(비율)
# Cognizant
# 순이익률(비율)
# Cognizant
# ROA(비율)
# Cognizant
# 영업이익(천원)
# Cognizant
# ROE(지배)(비율)
# Cognizant
# SG&A
# Cognizant
# 인당순이익s
# Cognizant
# EBIT(천원)
# Cognizant
# 영업이익률(비율)
# Cognizant
# ROGI(%)
# Cognizant
# Free Cash Flow2(천원)
# Cognizant
# 인당영업이익s
# Cognizant
# 현금배당성향(%)
# Cognizant
# EBITDA2마진율(비율)
# 활동성
# Cognizant
# 매입채무회전율
# Cognizant
# 재고자산회전율(비율)
# Cognizant
# 매출채권회전율
# Cognizant
# 무형자산회전율s
# ...
